# %%
import pandas as pd 
import numpy as np 
import math
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('research_student.csv')
df
# Out:
#     Branch  Marks[10th]  Marks[12th]  Gender Board[10th] Board[12th] Category  \
# 0      NaN          NaN          NaN     NaN         NaN         NaN      NaN
# 1    CIVIL        77.57         64.6    Male  BSEB Patna  BSEB Patna      OBC
# 2      CSE        86.40         71.8    Male        CBSE        CBSE      GEN
# 3      CSE        88.14         78.0    Male        ICSE        ICSE      GEN
# 4      CSE        65.40         59.8  Female        CBSE        CBSE       ST
# ..     ...          ...          ...     ...         ...         ...      ...
# 781    NaN          NaN          NaN     NaN         NaN         NaN      NaN
# 782    NaN          NaN          NaN     NaN         NaN         NaN      NaN
# 783    NaN          NaN          NaN     NaN         NaN         NaN      NaN
# 784    NaN          NaN          NaN     NaN         NaN         NaN      NaN
# 785    NaN          NaN          NaN     NaN         NaN         NaN      NaN
#
# ...

# %%
df.head()
# Out:
#   Branch  Marks[10th]  Marks[12th]  Gender Board[10th] Board[12th] Category  \
# 0    NaN          NaN          NaN     NaN         NaN         NaN      NaN
# 1  CIVIL        77.57         64.6    Male  BSEB Patna  BSEB Patna      OBC
# 2    CSE        86.40         71.8    Male        CBSE        CBSE      GEN
# 3    CSE        88.14         78.0    Male        ICSE        ICSE      GEN
# 4    CSE        65.40         59.8  Female        CBSE        CBSE       ST
#
#    GPA 1      Rank  Normalized Rank  ...  GPA 3  GPA 4  GPA 5  GPA 6  \
# 0    NaN       NaN              NaN  ...    NaN    NaN    NaN    NaN
# 1   6.29   44718.0        15.970714  ...   5.94   5.41   6.25   6.13
# 2   6.47   24222.0         8.650714  ...   5.88   5.53   6.44   6.19
# 3   7.35   24723.0         8.829643  ...   6.54   6.41   6.50   6.69
# 4   6.41  232157.0        82.913214  ...   5.71   5.24   5.88   6.25
#
#    Olympiads Qualified  Technical Projects  Tech Quiz  Engg. Coaching  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Branch                  220 non-null    object
#  1   Marks[10th]             220 non-null    float64
#  2   Marks[12th]             220 non-null    float64
#  3   Gender                  220 non-null    object
#  4   Board[10th]             220 non-null    object
#  5   Board[12th]             220 non-null    object
#  6   Category                220 non-null    object
#  7   GPA 1                   220 non-null    float64
#  8   Rank                    221 non-null    float64
#  9   Normalized Rank         220 non-null    float64
#  10  CGPA                    220 non-null    float64
#  11  Current Back            220 non-null    float64
#  12  Ever Back               219 non-null    float64
#  13  GPA 2                   220 non-null    float64
# ...

# %%
df.dtypes
# Out:
# Branch                     object
# Marks[10th]               float64
# Marks[12th]               float64
# Gender                     object
# Board[10th]                object
# Board[12th]                object
# Category                   object
# GPA 1                     float64
# Rank                      float64
# Normalized Rank           float64
# CGPA                      float64
# Current Back              float64
# Ever Back                 float64
# GPA 2                     float64
# GPA 3                     float64
# GPA 4                     float64
# GPA 5                     float64
# GPA 6                     float64
# Olympiads Qualified       float64
# Technical Projects        float64
# Tech Quiz                 float64
# Engg. Coaching            float64
# NTSE Scholarships         float64
# Miscellany Tech Events    float64
# dtype: object

# %%
df.isnull()
# Out:
#      Branch  Marks[10th]  Marks[12th]  Gender  Board[10th]  Board[12th]  \
# 0      True         True         True    True         True         True
# 1     False        False        False   False        False        False
# 2     False        False        False   False        False        False
# 3     False        False        False   False        False        False
# 4     False        False        False   False        False        False
# ..      ...          ...          ...     ...          ...          ...
# 781    True         True         True    True         True         True
# 782    True         True         True    True         True         True
# 783    True         True         True    True         True         True
# 784    True         True         True    True         True         True
# 785    True         True         True    True         True         True
#
#      Category  GPA 1   Rank  Normalized Rank  ...  GPA 3  GPA 4  GPA 5  GPA 6  \
# ...

# %%
df.isnull().sum()
# Out:
# Branch                    566
# Marks[10th]               566
# Marks[12th]               566
# Gender                    566
# Board[10th]               566
# Board[12th]               566
# Category                  566
# GPA 1                     566
# Rank                      565
# Normalized Rank           566
# CGPA                      566
# Current Back              566
# Ever Back                 567
# GPA 2                     566
# GPA 3                     566
# GPA 4                     566
# GPA 5                     566
# GPA 6                     566
# Olympiads Qualified       566
# Technical Projects        566
# Tech Quiz                 566
# Engg. Coaching            566
# NTSE Scholarships         566
# Miscellany Tech Events    566
# dtype: int64

# %%
m_v = df['Marks[10th]'].mean()
df['Marks[10th]'] = df['Marks[10th]'].fillna(value=m_v)
df
# Out:
#     Branch  Marks[10th]  Marks[12th]  Gender Board[10th] Board[12th] Category  \
# 0      NaN    84.307455          NaN     NaN         NaN         NaN      NaN
# 1    CIVIL    77.570000         64.6    Male  BSEB Patna  BSEB Patna      OBC
# 2      CSE    86.400000         71.8    Male        CBSE        CBSE      GEN
# 3      CSE    88.140000         78.0    Male        ICSE        ICSE      GEN
# 4      CSE    65.400000         59.8  Female        CBSE        CBSE       ST
# ..     ...          ...          ...     ...         ...         ...      ...
# 781    NaN    84.307455          NaN     NaN         NaN         NaN      NaN
# 782    NaN    84.307455          NaN     NaN         NaN         NaN      NaN
# 783    NaN    84.307455          NaN     NaN         NaN         NaN      NaN
# 784    NaN    84.307455          NaN     NaN         NaN         NaN      NaN
# 785    NaN    84.307455          NaN     NaN         NaN         NaN      NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Branch                    566
# Marks[10th]                 0
# Marks[12th]               566
# Gender                    566
# Board[10th]               566
# Board[12th]               566
# Category                  566
# GPA 1                     566
# Rank                      565
# Normalized Rank           566
# CGPA                      566
# Current Back              566
# Ever Back                 567
# GPA 2                     566
# GPA 3                     566
# GPA 4                     566
# GPA 5                     566
# GPA 6                     566
# Olympiads Qualified       566
# Technical Projects        566
# Tech Quiz                 566
# Engg. Coaching            566
# NTSE Scholarships         566
# Miscellany Tech Events    566
# dtype: int64

# %%
df['Branch'] = df['Branch'].ffill()
df
# Out:
#     Branch  Marks[10th]  Marks[12th]  Gender Board[10th] Board[12th] Category  \
# 0      NaN    84.307455          NaN     NaN         NaN         NaN      NaN
# 1    CIVIL    77.570000         64.6    Male  BSEB Patna  BSEB Patna      OBC
# 2      CSE    86.400000         71.8    Male        CBSE        CBSE      GEN
# 3      CSE    88.140000         78.0    Male        ICSE        ICSE      GEN
# 4      CSE    65.400000         59.8  Female        CBSE        CBSE       ST
# ..     ...          ...          ...     ...         ...         ...      ...
# 781   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
# 782   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
# 783   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
# 784   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
# 785   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
#
# ...

# %%
df['Branch'] = df['Branch'].bfill()
df
# Out:
#     Branch  Marks[10th]  Marks[12th]  Gender Board[10th] Board[12th] Category  \
# 0    CIVIL    84.307455          NaN     NaN         NaN         NaN      NaN
# 1    CIVIL    77.570000         64.6    Male  BSEB Patna  BSEB Patna      OBC
# 2      CSE    86.400000         71.8    Male        CBSE        CBSE      GEN
# 3      CSE    88.140000         78.0    Male        ICSE        ICSE      GEN
# 4      CSE    65.400000         59.8  Female        CBSE        CBSE       ST
# ..     ...          ...          ...     ...         ...         ...      ...
# 781   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
# 782   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
# 783   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
# 784   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
# 785   PROD    84.307455          NaN     NaN         NaN         NaN      NaN
#
# ...

# %%
df[['Gender', 'Board[10th]', 'Board[12th]', 'Category']] = df[['Gender', 'Board[10th]', 'Board[12th]', 'Category']].ffill()
df
# Out:
#     Branch  Marks[10th]  Marks[12th]  Gender Board[10th] Board[12th] Category  \
# 0    CIVIL    84.307455          NaN     NaN         NaN         NaN      NaN
# 1    CIVIL    77.570000         64.6    Male  BSEB Patna  BSEB Patna      OBC
# 2      CSE    86.400000         71.8    Male        CBSE        CBSE      GEN
# 3      CSE    88.140000         78.0    Male        ICSE        ICSE      GEN
# 4      CSE    65.400000         59.8  Female        CBSE        CBSE       ST
# ..     ...          ...          ...     ...         ...         ...      ...
# 781   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 782   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 783   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 784   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 785   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
#
# ...

# %%
df[['GPA 2', 'GPA 3', 'GPA 4', 'GPA 5', 'GPA 6', 'Olympiads Qualified']] = df[['GPA 2', 'GPA 3', 'GPA 4', 'GPA 5', 'GPA 6', 'Olympiads Qualified']].ffill()
df
# Out:
#     Branch  Marks[10th]  Marks[12th]  Gender Board[10th] Board[12th] Category  \
# 0    CIVIL    84.307455          NaN     NaN         NaN         NaN      NaN
# 1    CIVIL    77.570000         64.6    Male  BSEB Patna  BSEB Patna      OBC
# 2      CSE    86.400000         71.8    Male        CBSE        CBSE      GEN
# 3      CSE    88.140000         78.0    Male        ICSE        ICSE      GEN
# 4      CSE    65.400000         59.8  Female        CBSE        CBSE       ST
# ..     ...          ...          ...     ...         ...         ...      ...
# 781   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 782   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 783   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 784   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 785   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
#
# ...

# %%
df[['Gender', 'Board[10th]', 'Board[12th]', 'Category']] = df[['Gender', 'Board[10th]', 'Board[12th]', 'Category']].bfill()
df
# Out:
#     Branch  Marks[10th]  Marks[12th]  Gender Board[10th] Board[12th] Category  \
# 0    CIVIL    84.307455          NaN    Male  BSEB Patna  BSEB Patna      OBC
# 1    CIVIL    77.570000         64.6    Male  BSEB Patna  BSEB Patna      OBC
# 2      CSE    86.400000         71.8    Male        CBSE        CBSE      GEN
# 3      CSE    88.140000         78.0    Male        ICSE        ICSE      GEN
# 4      CSE    65.400000         59.8  Female        CBSE        CBSE       ST
# ..     ...          ...          ...     ...         ...         ...      ...
# 781   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 782   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 783   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 784   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
# 785   PROD    84.307455         83.2    Male        CBSE        CBSE      GEN
#
# ...

# %%
first_outlier = [786, 787, 'NA', 200, 'Female'] + [None] * (24 - 5)
second_outlier = [787, 788, 'ELEC', -100, 'Female'] + [None] * (24 - 5)

# %%
df.loc[786] = first_outlier
df.loc[787] = second_outlier
df
# Out:
#     Branch  Marks[10th] Marks[12th]  Gender Board[10th] Board[12th] Category  \
# 0    CIVIL    84.307455         NaN    Male  BSEB Patna  BSEB Patna      OBC
# 1    CIVIL    77.570000        64.6    Male  BSEB Patna  BSEB Patna      OBC
# 2      CSE    86.400000        71.8    Male        CBSE        CBSE      GEN
# 3      CSE    88.140000        78.0    Male        ICSE        ICSE      GEN
# 4      CSE    65.400000        59.8  Female        CBSE        CBSE       ST
# ..     ...          ...         ...     ...         ...         ...      ...
# 783   PROD    84.307455        83.2    Male        CBSE        CBSE      GEN
# 784   PROD    84.307455        83.2    Male        CBSE        CBSE      GEN
# 785   PROD    84.307455        83.2    Male        CBSE        CBSE      GEN
# 786    786   787.000000          NA     200      Female        None     None
# 787    787   788.000000        ELEC    -100      Female        None     None
#
# ...

# %%
df.boxplot('GPA 6')
plt.show()
