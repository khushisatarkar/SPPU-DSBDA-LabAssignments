# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('adult.csv')
df
# Out:
#        Age          Workclass  Final Weight    Education  EducationNum  \
# 0       39          State-gov         77516    Bachelors            13
# 1       50   Self-emp-not-inc         83311    Bachelors            13
# 2       38            Private        215646      HS-grad             9
# 3       53            Private        234721         11th             7
# 4       28            Private        338409    Bachelors            13
# ...    ...                ...           ...          ...           ...
# 32556   27            Private        257302   Assoc-acdm            12
# 32557   40            Private        154374      HS-grad             9
# 32558   58            Private        151910      HS-grad             9
# 32559   22            Private        201490      HS-grad             9
# 32560   52       Self-emp-inc        287927      HS-grad             9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
# empty dataframe to store the calculated statistics
results = pd.DataFrame()

# %%
newdf = df.select_dtypes(include = 'number')

# %%
for i in newdf.columns:
    mean = newdf[i].mean()
    median = newdf[i].median()
    mode = newdf[i].mode()
    minValue = newdf[i].min()
    maxValue = newdf[i].max()
    std = newdf[i].std()
    variance = newdf[i].var()
    percentile_25 = newdf[i].quantile(0.25)
    percentile_50 = newdf[i].quantile(0.50)
    percentile_75 = newdf[i].quantile(0.75)
    results[i] = [mean, median, mode, minValue, maxValue, std, variance, percentile_25, percentile_50, percentile_75]

# %%
results.index = ['Mean', 'Median', 'Mode', 'Min', 'Max', 'Standard Deviation', 'Variance', '25%', '50%', '75%']

# %%
print(results)
# Out:
#                                                 Age  \
# Mean                                      38.581647
# Median                                         37.0
# Mode                0    36
# Name: Age, dtype: int64
# Min                                              17
# Max                                              90
# Standard Deviation                        13.640433
# Variance                                   186.0614
# 25%                                            28.0
# 50%                                            37.0
# 75%                                            48.0
#
#                                                          Final Weight  \
# Mean                                                    189778.366512
# Median                                                       178356.0
# Mode                0    123011
# 1    164190
# 2    203488
# Name: Fina...
# Min                                                             12285
# ...

# %%
results
# Out:
#                                                 Age  \
# Mean                                      38.581647
# Median                                         37.0
# Mode                0    36
# Name: Age, dtype: int64
# Min                                              17
# Max                                              90
# Standard Deviation                        13.640433
# Variance                                   186.0614
# 25%                                            28.0
# 50%                                            37.0
# 75%                                            48.0
#
#                                                          Final Weight  \
# Mean                                                    189778.366512
# Median                                                       178356.0
# Mode                0    123011
# 1    164190
# 2    203488
# Name: Fina...
# Min                                                             12285
# ...
